# %%
DIR='/Users/ravali/Desktop/DataSciencetsf/data'
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
df1 = pd.read_csv(DIR+'/data1.csv', delimiter=',')
display(df1)
# Out:
#          Product_Code Warehouse Product_Category        Date Order_Demand
# 0        Product_0993    Whse_J     Category_028   2012/7/27         100
# 1        Product_0979    Whse_J     Category_028   2012/1/19         500
# 2        Product_0979    Whse_J     Category_028    2012/2/3         500
# 3        Product_0979    Whse_J     Category_028    2012/2/9         500
# 4        Product_0979    Whse_J     Category_028    2012/3/2         500
# 5        Product_0979    Whse_J     Category_028   2012/4/19         500
# 6        Product_0979    Whse_J     Category_028    2012/6/5         500
# 7        Product_0979    Whse_J     Category_028   2012/6/27         500
# 8        Product_0979    Whse_J     Category_028   2012/7/23         500
# 9        Product_0979    Whse_J     Category_028   2012/8/29         500
# 10       Product_0979    Whse_J     Category_028   2012/8/29         500
# 11       Product_0979    Whse_J     Category_028   2012/9/18         500
# ...

# %%
df1['year'] = pd.DatetimeIndex(df1['Date']).year

df1['month'] = pd.DatetimeIndex(df1['Date']).month

df1['day'] = pd.DatetimeIndex(df1['Date']).day
df5 = df1.groupby('year').count()['Order_Demand']
#display(df5)
display(df5)
# Out:
# year
# 2011.0       640
# 2012.0    203635
# 2013.0    218298
# 2014.0    216404
# 2015.0    209661
# 2016.0    188645
# 2017.0        53
# Name: Order_Demand, dtype: int64

# %%
df6 = df1.groupby('year').count()['Product_Category']
display(df6)
# Out:
# year
# 2011.0       640
# 2012.0    203635
# 2013.0    218298
# 2014.0    216404
# 2015.0    209661
# 2016.0    188645
# 2017.0        53
# Name: Product_Category, dtype: int64

# %%
df5.to_csv('/Users/ravali/Desktop/DataSciencetsf/data/Featureengineering1.csv', sep=',')
